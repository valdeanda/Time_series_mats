# %% [markdown]
# # Network Motifs barbplots

# %% [markdown]
# ## 1.  Load libraries

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt
import pandas as pd
import seaborn as sns
from scipy import stats
import numpy as np
import matplotlib
from matplotlib import cm
ncol = 12
values = np.linspace(0,1, ncol)
colors_ = cm.tab20(values)
#colors_ = cm.Paired(values)
sns.set_style("darkgrid")

# %% [markdown]
# # Total interactions

# %%
df=pd.read_table("../data/interactions")
df
# Out:
#    Site      Type  Percentage
# 0     A  positive       0.400
# 1     A  positive       0.375
# 2     A  positive       0.386
# 3     A  positive       0.376
# 4     A  negative       0.600
# 5     A  negative       0.625
# 6     A  negative       0.614
# 7     A  negative       0.624
# 8     B  positive       0.341
# 9     B  positive       0.849
# 10    B  positive       0.366
# 11    B  positive       0.346
# 12    B  negative       0.659
# 13    B  negative       0.151
# 14    B  negative       0.634
# 15    B  negative       0.654
# 16    C  positive       0.511
# 17    C  positive       0.516
# 18    C  positive       0.504
# 19    C  positive       0.475
# 20    C  negative       0.489
# 21    C  negative       0.484
# 22    C  negative       0.496
# 23    C  negative       0.525

# %%
my_pal = {"positive": "salmon", "negative": "gray"}

# %%
df.plot(kind="barh")

# %%
fig = plt.figure(figsize=(7,5))
sns.set(style='whitegrid')
sns.set(font_scale=1.3)
ax=sns.boxenplot(x="Site", y="Percentage", data=df, hue="Type",palette=my_pal,outlier_prop=0.8)
plt.ylabel("% of interactions", weight='bold', alpha=0.5)
plt.xlabel("Sites", weight="bold")
plt.tight_layout()
plt.savefig("../figures/06_Figure6.png",dpi=600)

# %%
fig = plt.figure(figsize=(7,5))
sns.set(style='whitegrid')
sns.set(font_scale=1.3)
ax=sns.boxplot(x="Site", y="Percentage", data=df, hue="Type",palette=my_pal, 
plt.ylabel("% of interactions", weight='bold', alpha=0.5)
plt.xlabel("Sites", weight="bold")
plt.tight_layout()
#plt.savefig("../figures/06_Figure6.png",dpi=600)

# %% [markdown]
# ## 2. Load data

# %% [markdown]
# From the output of mfinder:

# %%
# %%bash
# less ../data/motifs/a_class_consensus.txt
# Out:
#    Summary motif results
#    =====================
# mfinder Version 1.20
#
# MOTIF FINDER RESULTS:
#
# 	Network name: FORMAT_MFINDER_a_class_consensus.txt
# 	Network type: Directed
# 	Num of Nodes: 91 Num of Edges: 7888
# 	Num of Nodes with edges: 91
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#
# Full list of subgraphs size 3 ids:
#
# 	( Total num of different subgraphs size 3 is : 13 )
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	CREAL	UNIQ
# ID		STATS		ZSCORE	PVAL	[MILI]
# 6	52	52.0+-0.0	888888	1.000	0.43	1
#
# 12	6	6.0+-0.0	888888	1.000	0.05	1
#
# 14	3842	3842.0+-0.0	888888	1.000	31.99	2
#
# 36	0	0.0+-0.0	888888	1.000	0.00	0
#
# 38	30	30.0+-0.0	888888	1.000	0.25	1
#
# 46	2778	2778.0+-0.0	888888	1.000	23.13	5
#
# 74	0	0.0+-0.0	888888	1.000	0.00	0
#
# 78	0	0.0+-0.0	888888	1.000	0.00	0
#
# 98	0	0.0+-0.0	888888	1.000	0.00	0
#
# 102	28	28.0+-0.0	888888	1.000	0.23	2
#
# 108	58	58.0+-0.0	888888	1.000	0.48	3
#
# 110	3662	3662.0+-0.0	888888	1.000	30.49	7
#
# 238	109660	109660.0+-0.0	888888	1.000	912.95	29
#
#
#
#  (Application total runtime was:   5.47 minutes).
#
#  (Real network processing runtime was:    3.0 seconds.)
#
#  (Single Random network processing runtime was:    3.2 seconds.)

# %% [markdown]
# ### Parsing  outpout from MFINDER

# %% [markdown]
# ```bash
# #!/bin/bash
# cd ../data/motifs/
# for file  in *.txt; do grep -A  30 "Full list of subgraphs size 3 ids:" $file  | tail -n +5 | cut -f 1,2,5 | sed 's/ID//g' | sed 's/ZSCORE//g'| sed '/^\s*$/d'   | awk '$3<=0.05{print $0}'> $file.Pvalue.txt; done
# mv *.Pvalue.txt ../../motifs_out/
# cd ../data/motifs_out/
# find  -size 0 -delete
# tail -n +1  *.Pvalue.txt> toTable.motifs.txt
# sed 's/==>//g' toTable.motifs.txt  | sed 's/_consensus.txt.Pvalue.txt <==//g' | sed 's/_/ /g' > toTable.motifs.toexcel.txt
#
# ```

# %%
# %%bash
# head ../data/motifs_out/toTable.motifs.toexcel.txt
# Out:
#  a family
# 12	8201	0.030
#
#  a order
# 14	47660	0.000
# 38	12227	0.000
# 110	160069	0.010
#
#  b family
# 38	49611	0.000

# %%
consensus=pd.read_table("../data/motifs_out/consensus.tab", index_col=0)
negatives=pd.read_table("../data/motifs_out/negative.tab", index_col=0)
positives=pd.read_table("../data/motifs_out/positives.tab", index_col=0)

# %%
#old data
#consensus =pd.read_table("../data/Motifs_consensus.txt",index_col=0)
#positives =pd.read_table("../data/Motifs_postitives.txt",index_col=0)
#negatives =pd.read_table("../data/Motifs_negatives.txt", index_col=0)

# %% [markdown]
# ## 3. Visualize dataframe

# %%
consensus["74"]
# Out:
# Site_Level
# A_P         NaN
# A_C         NaN
# A_O         NaN
# A_F         NaN
# B_P         NaN
# B_C         NaN
# B_O         NaN
# B_F    0.271475
# C_P         NaN
# C_C         NaN
# C_O         NaN
# C_F         NaN
# G_P    0.003936
# G_C    0.010759
# G_O    0.065605
# G_F    0.648224
# Name: 74, dtype: float64

# %%
consensus= consensus/consensus.sum()
positives= positives/positives.sum()
negatives= negatives/negatives.sum()
consensus
# Out:
#                    6        12   14   36        38        46        74  \
# Site_Level
# A_P              NaN       NaN  NaN  NaN       NaN       NaN       NaN
# A_C              NaN       NaN  NaN  NaN       NaN       NaN       NaN
# A_O              NaN       NaN  1.0  NaN  0.179782       NaN       NaN
# A_F              NaN  0.180706  NaN  NaN       NaN       NaN       NaN
# B_P              NaN       NaN  NaN  NaN       NaN       NaN       NaN
# B_C              NaN       NaN  NaN  NaN       NaN       NaN       NaN
# B_O              NaN  0.005751  NaN  NaN       NaN       NaN       NaN
# B_F              NaN       NaN  NaN  NaN  0.729466  0.268821  0.271475
# C_P              NaN       NaN  NaN  NaN       NaN       NaN       NaN
# C_C         0.125921  0.003041  NaN  NaN       NaN  0.036932       NaN
# C_O         0.231103  0.017275  NaN  1.0       NaN  0.101082       NaN
# C_F         0.642977  0.176035  NaN  NaN       NaN  0.287169       NaN
# G_P              NaN  0.003834  NaN  NaN  0.003220  0.004819  0.003936
# G_C              NaN  0.028293  NaN  NaN  0.024246  0.032663  0.010759
# G_O              NaN  0.107463  NaN  NaN  0.063285  0.065643  0.065605
# G_F              NaN  0.477602  NaN  NaN       NaN  0.202871  0.648224
#
#                   78   98  102       108  110       238
# Site_Level
# A_P              NaN  NaN  NaN       NaN  NaN       NaN
# A_C              NaN  NaN  NaN       NaN  NaN       NaN
# A_O              NaN  NaN  NaN       NaN  1.0       NaN
# A_F              NaN  NaN  NaN       NaN  NaN       NaN
# B_P              NaN  NaN  NaN       NaN  NaN       NaN
# B_C              NaN  NaN  NaN       NaN  NaN       NaN
# B_O              NaN  NaN  NaN       NaN  NaN       NaN
# B_F         0.556191  NaN  NaN       NaN  NaN       NaN
# C_P              NaN  NaN  NaN       NaN  NaN       NaN
# C_C              NaN  NaN  NaN       NaN  NaN       NaN
# C_O         0.443809  1.0  NaN       NaN  NaN       NaN
# C_F              NaN  NaN  NaN  0.392424  NaN  0.698127
# G_P              NaN  NaN  NaN       NaN  NaN       NaN
# G_C              NaN  NaN  NaN       NaN  NaN  0.047426
# G_O              NaN  NaN  NaN       NaN  NaN  0.254447
# G_F              NaN  NaN  NaN  0.607576  NaN       NaN

# %%
sns.set(font_scale=1.5)
fig = plt.figure(figsize=(15,7))
ax=sns.heatmap(consensus,linewidths=0.6,cmap=sns.color_palette("rainbow", 5))
plt.title("Network motifs  in consensus networks", weight="bold", size="large")
#Old figure
#plt.xticks(rotation = 360)
#ax=sns.heatmap(consensus,linewidths=0.6,cmap=sns.color_palette("husl", 5))
#ax=consensus.plot(kind='bar',figsize=(12,5), colors=colors_)
#ax=sitea.T.plot(kind='bar',figsize=(12,4))#plt.ylim(0,5000000)
#plt.legend(bbox_to_anchor=(1, 1), loc=2, borderaxespad=0.05 ,labelspacing=0.25)
#plt.axvspan(5.5,6.5, alpha=0.1, color='salmon')
plt.tight_layout()
plt.savefig("../figures/Motifs_consensus.png",dpi=600,bbox_inches='tight')

# %%
sns.set(font_scale=1.5)
fig = plt.figure(figsize=(15,7))
ax=sns.heatmap(negatives,linewidths=0.6,cmap=sns.color_palette("rainbow", 5))
plt.title("Network motifs  in negative networks", weight="bold", size="large")
plt.tight_layout()
#plt.savefig("../figures/Motifs_negatives.png",dpi=600,bbox_inches='tight')

# %%
sns.set(font_scale=1.5)
fig = plt.figure(figsize=(15,7))
ax=sns.heatmap(positives,linewidths=0.6,cmap=sns.color_palette("rainbow", 5))
plt.title("Network motifs  in positive networks", weight="bold", size="large")
plt.tight_layout()
plt.savefig("../figures/Motifs_positives.png",dpi=600,bbox_inches='tight')
